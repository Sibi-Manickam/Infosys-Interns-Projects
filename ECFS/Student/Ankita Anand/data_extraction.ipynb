# %% [markdown]
# <h1>Energy Consumption Forecasting</h1>
#
# Real-time daily data for Energy Met and Daily Maximum Load at the national level taken from Grid-India (Grid Controller of India Limited) National Despatch Centre.
#
# Data source: https://report.grid-india.in/psp_report.php

# %% [markdown]
# <h2>Data Extraction</h2>
#
# Using BeautifulSoup and requests libraries, downloading and saving daily data into folders

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import os


# Base URL of the website
base_url = 'https://report.grid-india.in'

# Function to generate the form data for a given date
def generate_form_data(date):
    return {
        'selected_date': date.strftime('%Y-%m-%d')
    }

# Function to download a file from a URL
def download_file(url, save_dir, file_name):
    response = requests.get(url)
    if response.status_code == 200:
        file_path = os.path.join(save_dir, file_name)
        with open(file_path, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded: {file_name}")
    else:
        print(f"Failed to download {file_name}")

# Function to extract and download PDF reports from the form submission response
def extract_and_download_pdfs(response_text, save_dir):
    soup = BeautifulSoup(response_text, 'html.parser')
    links = soup.find_all('a', href=True)
    for link in links:
        url = link['href']
        if url.endswith('.pdf'):  # Check if the link is for a PDF file
            if not url.startswith('http'):
                url = base_url + url[1:]  # Ensure the URL is absolute
            file_name = url.split('/')[-1]
            download_file(url, save_dir, file_name)

# Main function to download PDF reports over a date range
def download_reports(start_date, end_date, save_dir):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    url = base_url + '/psp_report.php'  # Form submission URL
    current_date = start_date
    while current_date <= end_date:
        form_data = generate_form_data(current_date)
        response = requests.post(url, data=form_data)
        if response.status_code == 200:
            extract_and_download_pdfs(response.text, save_dir)
        else:
            print(f"Failed to fetch report for {current_date.strftime('%Y-%m-%d')}")
        current_date += timedelta(days=1)

# Example usage
start_date = datetime(2020, 1, 1)
end_date = datetime(2020, 12, 31)
save_dir = 'reports\\2020'

download_reports(start_date, end_date, save_dir)
# Out:
# Downloaded: 01.01.20_NLDC_PSP.pdf
# Downloaded: 02.01.20_NLDC_PSP.pdf
# Downloaded: 03.01.20_NLDC_PSP.pdf
# Downloaded: 04.01.20_NLDC_PSP.pdf
# Downloaded: 05.01.20_NLDC_PSP.pdf
# Downloaded: 06.01.20_NLDC_PSP.pdf
# Downloaded: 07.01.20_NLDC_PSP.pdf
# Downloaded: 08.01.20_NLDC_PSP.pdf
# Downloaded: 09.01.20_NLDC_PSP.pdf
# Downloaded: 10.01.20_NLDC_PSP.pdf
# Downloaded: 11.01.20_NLDC_PSP.pdf
# Downloaded: 12.01.20_NLDC_PSP.pdf
# Downloaded: 13.01.20_NLDC_PSP.pdf
# Downloaded: 14.01.20_NLDC_PSP.pdf
# Downloaded: 16.01.20_NLDC_PSP.pdf
# Downloaded: 17.01.20_NLDC_PSP.pdf
# Downloaded: 18.01.20_NLDC_PSP.pdf
# Downloaded: 19.01.20_NLDC_PSP.pdf
# Downloaded: 20.01.20_NLDC_PSP.pdf
# Downloaded: 21.01.20_NLDC_PSP.pdf
# Downloaded: 22.01.20_NLDC_PSP.pdf
# Downloaded: 23.01.20_NLDC_PSP.pdf
# Downloaded: 24.01.20_NLDC_PSP.pdf
# Downloaded: 25.01.20_NLDC_PSP.pdf
# Downloaded: 26.01.20_NLDC_PSP.pdf
# Downloaded: 27.01.20_NLDC_PSP.pdf
# Downloaded: 28.01.20_NLDC_PSP.pdf
# Downloaded: 29.01.20_NLDC_PSP.pdf
# Downloaded: 30.01.20_NLDC_PSP.pdf
# Downloaded: 31.01.20_NLDC_PSP.pdf
# Downloaded: 01.02.20_NLDC_PSP.pdf
# Downloaded: 02.02.20_NLDC_PSP.pdf
# Downloaded: 03.02.20_NLDC_PSP.pdf
# Downloaded: 04.02.20_NLDC_PSP.pdf
# Downloaded: 05.02.20_NLDC_PSP.pdf
# Downloaded: 06.02.20_NLDC_PSP.pdf
# Downloaded: 07.02.20_NLDC_PSP.pdf
# Downloaded: 08.02.20_NLDC_PSP.pdf
# Downloaded: 09.02.20_NLDC_PSP.pdf
# Downloaded: 10.02.20_NLDC_PSP.pdf
# Downloaded: 11.02.20_NLDC_PSP.pdf
# Downloaded: 12.02.20_NLDC_PSP.pdf
# Downloaded: 13.02.20_NLDC_PSP.pdf
# Downloaded: 14.02.20_NLDC_PSP.pdf
# Downloaded: 17.02.20_NLDC_PSP.pdf
# Downloaded: 18.02.20_NLDC_PSP.pdf
# Downloaded: 19.02.20_NLDC_PSP.pdf
# Downloaded: 20.02.20_NLDC_PSP.pdf
# Downloaded: 21.02.20_NLDC_PSP.pdf
# Downloaded: 22.02.20_NLDC_PSP.pdf
# Downloaded: 23.02.20_NLDC_PSP.pdf
# Downloaded: 24.02.20_NLDC_PSP.pdf
# Downloaded: 25.02.20_NLDC_PSP.pdf
# Downloaded: 26.02.20_NLDC_PSP.pdf
# Downloaded: 27.02.20_NLDC_PSP.pdf
# Downloaded: 28.02.20_NLDC_PSP.pdf
# Downloaded: 29.02.20_NLDC_PSP.pdf
# Downloaded: 01.03.20_NLDC_PSP.pdf
# Downloaded: 02.03.20_NLDC_PSP.pdf
# Downloaded: 03.03.20_NLDC_PSP.pdf
# Downloaded: 04.03.20_NLDC_PSP.pdf
# Downloaded: 05.03.20_NLDC_PSP.pdf
# Downloaded: 06.03.20_NLDC_PSP.pdf
# Downloaded: 07.03.20_NLDC_PSP.pdf
# Downloaded: 08.03.20_NLDC_PSP.pdf
# Downloaded: 09.03.20_NLDC_PSP.pdf
# Downloaded: 10.03.20_NLDC_PSP.pdf
# Downloaded: 11.03.20_NLDC_PSP.pdf
# Downloaded: 12.03.20_NLDC_PSP.pdf
# Downloaded: 13.03.20_NLDC_PSP.pdf
# Downloaded: 14.03.20_NLDC_PSP.pdf
# Downloaded: 15.03.20_NLDC_PSP.pdf
# Downloaded: 16.03.20_NLDC_PSP.pdf
# Downloaded: 17.03.20_NLDC_PSP.pdf
# Downloaded: 18.03.20_NLDC_PSP.pdf
# Downloaded: 19.03.20_NLDC_PSP.pdf
# Downloaded: 20.03.20_NLDC_PSP.pdf
# Downloaded: 21.03.20_NLDC_PSP.pdf
# Downloaded: 22.03.20_NLDC_PSP.pdf
# Downloaded: 23.03.20_NLDC_PSP.pdf
# Downloaded: 24.03.20_NLDC_PSP.pdf
# Downloaded: 25.03.20_NLDC_PSP.pdf
# Downloaded: 26.03.20_NLDC_PSP.pdf
# Downloaded: 27.03.20_NLDC_PSP.pdf
# Downloaded: 28.03.20_NLDC_PSP.pdf
# Downloaded: 29.03.20_NLDC_PSP.pdf
# Downloaded: 30.03.20_NLDC_PSP.pdf
# Downloaded: 31.03.20_NLDC_PSP.pdf
# Downloaded: 01.04.20_NLDC_PSP.pdf
# Downloaded: 02.04.20_NLDC_PSP.pdf
# Downloaded: 03.04.20_NLDC_PSP.pdf
# Downloaded: 04.04.20_NLDC_PSP.pdf
# Downloaded: 05.04.20_NLDC_PSP.pdf
# Downloaded: 06.04.20_NLDC_PSP.pdf
# Downloaded: 07.04.20_NLDC_PSP.pdf
# Downloaded: 08.04.20_NLDC_PSP.pdf
# Downloaded: 09.04.20_NLDC_PSP.pdf
# Downloaded: 10.04.20_NLDC_PSP.pdf
# Downloaded: 11.04.20_NLDC_PSP.pdf
# Downloaded: 12.04.20_NLDC_PSP.pdf
# Downloaded: 13.04.20_NLDC_PSP.pdf
# Downloaded: 14.04.20_NLDC_PSP.pdf
# Downloaded: 15.04.20_NLDC_PSP.pdf
# Downloaded: 17.04.20_NLDC_PSP.pdf
# Downloaded: 18.04.20_NLDC_PSP.pdf
# Downloaded: 19.04.20_NLDC_PSP.pdf
# Downloaded: 20.04.20_NLDC_PSP.pdf
# Downloaded: 21.04.20_NLDC_PSP.pdf
# Downloaded: 22.04.20_NLDC_PSP.pdf
# Downloaded: 23.04.20_NLDC_PSP.pdf
# Downloaded: 24.04.20_NLDC_PSP.pdf
# Downloaded: 25.04.20_NLDC_PSP.pdf
# Downloaded: 26.04.20_NLDC_PSP.pdf
# Downloaded: 27.04.20_NLDC_PSP.pdf
# Downloaded: 28.04.20_NLDC_PSP.pdf
# Downloaded: 29.04.20_NLDC_PSP.pdf
# Downloaded: 30.04.20_NLDC_PSP.pdf
# Downloaded: 01.05.20_NLDC_PSP.pdf
# Downloaded: 02.05.20_NLDC_PSP.pdf
# Downloaded: 03.05.20_NLDC_PSP.pdf
# Downloaded: 04.05.20_NLDC_PSP.pdf
# Downloaded: 05.05.20_NLDC_PSP.pdf
# Downloaded: 06.05.20_NLDC_PSP.pdf
# Downloaded: 07.05.20_NLDC_PSP.pdf
# Downloaded: 08.05.20_NLDC_PSP.pdf
# Downloaded: 09.05.20_NLDC_PSP.pdf
# Downloaded: 10.05.20_NLDC_PSP.pdf
# Downloaded: 11.05.20_NLDC_PSP.pdf
# Downloaded: 12.05.20_NLDC_PSP.pdf
# Downloaded: 13.05.20_NLDC_PSP.pdf
# Downloaded: 14.05.20_NLDC_PSP.pdf
# Downloaded: 15.05.20_NLDC_PSP.pdf
# Downloaded: 16.05.20_NLDC_PSP.pdf
# Downloaded: 17.05.20_NLDC_PSP.pdf
# Downloaded: 18.05.20_NLDC_PSP.pdf
# Downloaded: 19.05.20_NLDC_PSP.pdf
# Downloaded: 20.05.20_NLDC_PSP.pdf
# Downloaded: 21.05.20_NLDC_PSP.pdf
# Downloaded: 22.05.20_NLDC_PSP.pdf
# Downloaded: 23.05.20_NLDC_PSP.pdf
# Downloaded: 24.05.20_NLDC_PSP.pdf
# Downloaded: 25.05.20_NLDC_PSP.pdf
# Downloaded: 26.05.20_NLDC_PSP.pdf
# Downloaded: 27.05.20_NLDC_PSP.pdf
# Downloaded: 28.05.20_NLDC_PSP.pdf
# Downloaded: 29.05.20_NLDC_PSP.pdf
# Downloaded: 30.05.20_NLDC_PSP.pdf
# Downloaded: 31.05.20_NLDC_PSP.pdf
# Downloaded: 01.06.20_NLDC_PSP.pdf
# Downloaded: 02.06.20_NLDC_PSP.pdf
# Downloaded: 03.06.20_NLDC_PSP.pdf
# Downloaded: 04.06.20_NLDC_PSP.pdf
# Downloaded: 05.06.20_NLDC_PSP.pdf
# Downloaded: 06.06.20_NLDC_PSP.pdf
# Downloaded: 07.06.20_NLDC_PSP.pdf
# Downloaded: 08.06.20_NLDC_PSP.pdf
# Downloaded: 09.06.20_NLDC_PSP.pdf
# Downloaded: 10.06.20_NLDC_PSP.pdf
# Downloaded: 11.06.20_NLDC_PSP.pdf
# Downloaded: 12.06.20_NLDC_PSP.pdf
# Downloaded: 13.06.20_NLDC_PSP.pdf
# Downloaded: 14.06.20_NLDC_PSP.pdf
# Downloaded: 15.06.20_NLDC_PSP.pdf
# Downloaded: 16.06.20_NLDC_PSP.pdf
# Downloaded: 17.06.20_NLDC_PSP.pdf
# Downloaded: 18.06.20_NLDC_PSP.pdf
# Downloaded: 19.06.20_NLDC_PSP.pdf
# Downloaded: 20.06.20_NLDC_PSP.pdf
# Downloaded: 21.06.20_NLDC_PSP.pdf
# Downloaded: 22.06.20_NLDC_PSP.pdf
# Downloaded: 23.06.20_NLDC_PSP.pdf
# Downloaded: 24.06.20_NLDC_PSP.pdf
# Downloaded: 25.06.20_NLDC_PSP.pdf
# Downloaded: 26.06.20_NLDC_PSP.pdf
# Downloaded: 27.06.20_NLDC_PSP.pdf
# Downloaded: 28.06.20_NLDC_PSP.pdf
# Downloaded: 29.06.20_NLDC_PSP.pdf
# Downloaded: 30.06.20_NLDC_PSP.pdf
# Downloaded: 01.07.20_NLDC_PSP.pdf
# Downloaded: 02.07.20_NLDC_PSP.pdf
# Downloaded: 03.07.20_NLDC_PSP.pdf
# Downloaded: 04.07.20_NLDC_PSP.pdf
# Downloaded: 05.07.20_NLDC_PSP.pdf
# Downloaded: 06.07.20_NLDC_PSP.pdf
# Downloaded: 07.07.20_NLDC_PSP.pdf
# Downloaded: 08.07.20_NLDC_PSP.pdf
# Downloaded: 09.07.20_NLDC_PSP.pdf
# Downloaded: 10.07.20_NLDC_PSP.pdf
# Downloaded: 11.07.20_NLDC_PSP.pdf
# Downloaded: 12.07.20_NLDC_PSP.pdf
# Downloaded: 13.07.20_NLDC_PSP.pdf
# Downloaded: 14.07.20_NLDC_PSP.pdf
# Downloaded: 17.07.20_NLDC_PSP.pdf
# Downloaded: 18.07.20_NLDC_PSP.pdf
# Downloaded: 19.07.20_NLDC_PSP.pdf
# Downloaded: 20.07.20_NLDC_PSP.pdf
# Downloaded: 21.07.20_NLDC_PSP.pdf
# Downloaded: 22.07.20_NLDC_PSP.pdf
# Downloaded: 23.07.20_NLDC_PSP.pdf
# Downloaded: 24.07.20_NLDC_PSP.pdf
# Downloaded: 25.07.20_NLDC_PSP.pdf
# Downloaded: 26.07.20_NLDC_PSP.pdf
# Downloaded: 27.07.20_NLDC_PSP.pdf
# Downloaded: 28.07.20_NLDC_PSP.pdf
# Downloaded: 29.07.20_NLDC_PSP.pdf
# Downloaded: 30.07.20_NLDC_PSP.pdf
# Downloaded: 31.07.20_NLDC_PSP.pdf
# Downloaded: 01.08.20_NLDC_PSP.pdf
# Downloaded: 02.08.20_NLDC_PSP.pdf
# Downloaded: 03.08.20_NLDC_PSP.pdf
# Downloaded: 04.08.20_NLDC_PSP.pdf
# Downloaded: 05.08.20_NLDC_PSP.pdf
# Downloaded: 06.08.20_NLDC_PSP.pdf
# Downloaded: 07.08.20_NLDC_PSP.pdf
# Downloaded: 08.08.20_NLDC_PSP.pdf
# Downloaded: 09.08.20_NLDC_PSP.pdf
# Downloaded: 10.08.20_NLDC_PSP.pdf
# Downloaded: 11.08.20_NLDC_PSP.pdf
# Downloaded: 12.08.20_NLDC_PSP.pdf
# Downloaded: 13.08.20_NLDC_PSP.pdf
# Downloaded: 14.08.20_NLDC_PSP.pdf
# Downloaded: 15.08.20_NLDC_PSP.pdf
# Downloaded: 17.08.20_NLDC_PSP.pdf
# Downloaded: 18.08.20_NLDC_PSP.pdf
# Downloaded: 19.08.20_NLDC_PSP.pdf
# Downloaded: 20.08.20_NLDC_PSP.pdf
# Downloaded: 21.08.20_NLDC_PSP.pdf
# Downloaded: 22.08.20_NLDC_PSP.pdf
# Downloaded: 23.08.20_NLDC_PSP.pdf
# Downloaded: 24.08.20_NLDC_PSP.pdf
# Downloaded: 25.08.20_NLDC_PSP.pdf
# Downloaded: 26.08.20_NLDC_PSP.pdf
# Downloaded: 27.08.20_NLDC_PSP.pdf
# Downloaded: 28.08.20_NLDC_PSP.pdf
# Downloaded: 29.08.20_NLDC_PSP.pdf
# Downloaded: 30.08.20_NLDC_PSP.pdf
# Downloaded: 31.08.20_NLDC_PSP.pdf
# Downloaded: 01.09.20_NLDC_PSP.pdf
# Downloaded: 02.09.20_NLDC_PSP.pdf
# Downloaded: 03.09.20_NLDC_PSP.pdf
# Downloaded: 04.09.20_NLDC_PSP.pdf
# Downloaded: 05.09.20_NLDC_PSP.pdf
# Downloaded: 06.09.20_NLDC_PSP.pdf
# Downloaded: 07.09.20_NLDC_PSP.pdf
# Downloaded: 08.09.20_NLDC_PSP.pdf
# Downloaded: 09.09.20_NLDC_PSP.pdf
# Downloaded: 10.09.20_NLDC_PSP.pdf
# Downloaded: 11.09.20_NLDC_PSP.pdf
# Downloaded: 12.09.20_NLDC_PSP.pdf
# Downloaded: 13.09.20_NLDC_PSP.pdf
# Downloaded: 14.09.20_NLDC_PSP.pdf
# Downloaded: 16.09.20_NLDC_PSP.pdf
# Downloaded: 17.09.20_NLDC_PSP.pdf
# Downloaded: 18.09.20_NLDC_PSP.pdf
# Downloaded: 19.09.20_NLDC_PSP.pdf
# Downloaded: 20.09.20_NLDC_PSP.pdf
# Downloaded: 21.09.20_NLDC_PSP.pdf
# Downloaded: 22.09.20_NLDC_PSP.pdf
# Downloaded: 23.09.20_NLDC_PSP.pdf
# Downloaded: 24.09.20_NLDC_PSP.pdf
# Downloaded: 25.09.20_NLDC_PSP.pdf
# Downloaded: 26.09.20_NLDC_PSP.pdf
# Downloaded: 27.09.20_NLDC_PSP.pdf
# Downloaded: 28.09.20_NLDC_PSP.pdf
# Downloaded: 29.09.20_NLDC_PSP.pdf
# Downloaded: 30.09.20_NLDC_PSP.pdf
# Downloaded: 01.10.20_NLDC_PSP.pdf
# Downloaded: 02.10.20_NLDC_PSP.pdf
# Downloaded: 03.10.20_NLDC_PSP.pdf
# Downloaded: 04.10.20_NLDC_PSP.pdf
# Downloaded: 05.10.20_NLDC_PSP.pdf
# Downloaded: 06.10.20_NLDC_PSP.pdf
# Downloaded: 07.10.20_NLDC_PSP.pdf
# Downloaded: 08.10.20_NLDC_PSP.pdf
# Downloaded: 09.10.20_NLDC_PSP.pdf
# Downloaded: 10.10.20_NLDC_PSP.pdf
# Downloaded: 11.10.20_NLDC_PSP.pdf
# Downloaded: 12.10.20_NLDC_PSP.pdf
# Downloaded: 13.10.20_NLDC_PSP.pdf
# Downloaded: 14.10.20_NLDC_PSP.pdf
# Downloaded: 15.10.20_NLDC_PSP.pdf
# Downloaded: 16.10.20_NLDC_PSP.pdf
# Downloaded: 17.10.20_NLDC_PSP.pdf
# Downloaded: 18.10.20_NLDC_PSP.pdf
# Downloaded: 19.10.20_NLDC_PSP.pdf
# Downloaded: 20.10.20_NLDC_PSP.pdf
# Downloaded: 21.10.20_NLDC_PSP.pdf
# Downloaded: 22.10.20_NLDC_PSP.pdf
# Downloaded: 23.10.20_NLDC_PSP.pdf
# Downloaded: 24.10.20_NLDC_PSP.pdf
# Downloaded: 25.10.20_NLDC_PSP.pdf
# Downloaded: 26.10.20_NLDC_PSP.pdf
# Downloaded: 27.10.20_NLDC_PSP.pdf
# Downloaded: 29.10.20_NLDC_PSP.pdf
# Downloaded: 30.10.20_NLDC_PSP.pdf
# Downloaded: 31.10.20_NLDC_PSP.pdf
# Downloaded: 01.11.20_NLDC_PSP.pdf
# Downloaded: 02.11.20_NLDC_PSP.pdf
# Downloaded: 03.11.20_NLDC_PSP.pdf
# Downloaded: 04.11.20_NLDC_PSP.pdf
# Downloaded: 05.11.20_NLDC_PSP.pdf
# Downloaded: 06.11.20_NLDC_PSP.pdf
# Downloaded: 07.11.20_NLDC_PSP.pdf
# Downloaded: 08.11.20_NLDC_PSP.pdf
# Downloaded: 09.11.20_NLDC_PSP.pdf
# Downloaded: 10.11.20_NLDC_PSP.pdf
# Downloaded: 11.11.20_NLDC_PSP.pdf
# Downloaded: 12.11.20_NLDC_PSP.pdf
# Downloaded: 13.11.20_NLDC_PSP.pdf
# Downloaded: 15.11.20_NLDC_PSP.pdf
# Downloaded: 16.11.20_NLDC_PSP.pdf
# Downloaded: 17.11.20_NLDC_PSP.pdf
# Downloaded: 18.11.20_NLDC_PSP.pdf
# Downloaded: 19.11.20_NLDC_PSP.pdf
# Downloaded: 20.11.20_NLDC_PSP.pdf
# Downloaded: 21.11.20_NLDC_PSP.pdf
# Downloaded: 22.11.20_NLDC_PSP.pdf
# Downloaded: 23.11.20_NLDC_PSP.pdf
# Downloaded: 24.11.20_NLDC_PSP.pdf
# Downloaded: 25.11.20_NLDC_PSP.pdf
# Downloaded: 26.11.20_NLDC_PSP.pdf
# Downloaded: 27.11.20_NLDC_PSP.pdf
# Downloaded: 28.11.20_NLDC_PSP.pdf
# Downloaded: 29.11.20_NLDC_PSP.pdf
# Downloaded: 30.11.20_NLDC_PSP.pdf
# Downloaded: 01.12.20_NLDC_PSP.pdf
# Downloaded: 02.12.20_NLDC_PSP.pdf
# Downloaded: 03.12.20_NLDC_PSP.pdf
# Downloaded: 04.12.20_NLDC_PSP.pdf
# Downloaded: 05.12.20_NLDC_PSP.pdf
# Downloaded: 06.12.20_NLDC_PSP.pdf
# Downloaded: 07.12.20_NLDC_PSP.pdf
# Downloaded: 08.12.20_NLDC_PSP.pdf
# Downloaded: 09.12.20_NLDC_PSP.pdf
# Downloaded: 10.12.20_NLDC_PSP.pdf
# Downloaded: 11.12.20_NLDC_PSP.pdf
# Downloaded: 12.12.20_NLDC_PSP.pdf
# Downloaded: 13.12.20_NLDC_PSP.pdf
# Downloaded: 14.12.20_NLDC_PSP.pdf
# Downloaded: 18.12.20_NLDC_PSP.pdf
# Downloaded: 19.12.20_NLDC_PSP.pdf
# Downloaded: 20.12.20_NLDC_PSP.pdf
# Downloaded: 21.12.20_NLDC_PSP.pdf
# Downloaded: 22.12.20_NLDC_PSP.pdf
# Downloaded: 23.12.20_NLDC_PSP.pdf
# Downloaded: 24.12.20_NLDC_PSP.pdf
# Downloaded: 25.12.20_NLDC_PSP.pdf
# Downloaded: 26.12.20_NLDC_PSP.pdf
# Downloaded: 27.12.20_NLDC_PSP.pdf
# Downloaded: 28.12.20_NLDC_PSP.pdf
# Downloaded: 29.12.20_NLDC_PSP.pdf
# Downloaded: 30.12.20_NLDC_PSP.pdf
# Downloaded: 31.12.20_NLDC_PSP.pdf

# %% [markdown]
# Iterating through the folder containing the PDF files, extracting the required data from the files and writing it into csv files for later use.
#
# I'm doing this year-wise in order to incorporate minor changes in the format of the PDF files.

# %%
import os
import pandas as pd
from tabula import read_pdf
import warnings

count = 0

# Function to process a single PDF file
def process_pdf(pdf_path):
    try:

         # Suppress warnings from tabula
        warnings.filterwarnings("ignore", category=UserWarning, message=".*Fallback font.*")

        # Extract date from the file path
        parts = pdf_path.split("\\")
        date_part = parts[-1].split("_")[0]
        day, month, year = map(int, date_part.split("."))
        date = pd.to_datetime(f'{int(year) + 2000}-{month}-{day}')
        
        # Extract tables from page 2 
        tables = read_pdf(pdf_path, pages="2", multiple_tables=True)

        # Check if any tables were found
        if not tables:
            print(f"No tables found on page 2 of the PDF: {pdf_path}")
            return None, None

        df = tables[2]
        state_col = df.columns[1]
        max_demand_column = df.columns[3]
        energy_met_column = df.columns[5]
        df.rename(columns={state_col: 'State', max_demand_column: 'Max.Demand', energy_met_column: 'Energy Met'}, inplace=True)
        df = df[['State', 'Max.Demand', 'Energy Met']]

        # Find the index to start from (Punjab)
        index_to_keep_from = df[df['State'] == 'Punjab'].index[0]
        index_to_stop=df[df['State'] == 'Tripura'].index[0]
        df = df.loc[index_to_keep_from:index_to_stop]
        df.reset_index(drop=True, inplace=True)

        return date, df
       
    except Exception as e:
        print(f"Error processing file {pdf_path}: {e}")
        return None, None

# Folder containing PDF files
pdf_folder = "reports\\2020"

# Initialize lists to store data for energy_met and maximum_demand dataframes
energy_met_data = []
maximum_demand_data = []

# Iterate through PDF files in the folder
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)
        date, df = process_pdf(pdf_path)
        if date is not None and df is not None:
            try:
                states = df['State'].tolist()
                energy_met_data.append([date] + df['Energy Met'].tolist())
                maximum_demand_data.append([date] + df['Max.Demand'].tolist())
                count += 1
                print(f"Dataframe appended: {date}   ...{count}")
                
            except Exception as e:
                print(f"Error appending data for date {date}: {e}")
# Out:
# Dataframe appended: 2020-03-22 00:00:00   ...1
# Dataframe appended: 2020-03-23 00:00:00   ...2
# Dataframe appended: 2020-03-24 00:00:00   ...3
# Dataframe appended: 2020-03-28 00:00:00   ...4
# Dataframe appended: 2020-03-29 00:00:00   ...5
# Dataframe appended: 2020-03-30 00:00:00   ...6
# Dataframe appended: 2020-03-31 00:00:00   ...7

# %%
for el in energy_met_data:
    if len(el)!=37:
        print(energy_met_data.index(el)+1, len(el))


print(len(states))
# Out:
# 36

# %%
# Create energy_met and maximum_demand dataframes
energy_met_df = pd.DataFrame(energy_met_data,columns=['Date'] + states)
maximum_demand_df = pd.DataFrame(maximum_demand_data,columns=['Date'] + states)


# Display the final dataframes
print("Energy Met:\n", energy_met_df)
print("\nMaximum Demand:\n", maximum_demand_df)
# Out:
# Energy Met:
#          Date Punjab Haryana Rajasthan Delhi     UP Uttarakhand    HP  \
# 0 2020-03-22  105.7   115.1     202.4  59.1  255.7        33.4  21.1
# 1 2020-03-23   86.3    93.0     178.7  46.1  240.8        22.5  18.0
# 2 2020-03-24   74.7    92.0     171.9  48.7  247.4        21.7  20.5
# 3 2020-03-28   57.6    65.9     105.8  44.4  217.3        17.0  12.9
# 4 2020-03-29   60.0    66.5     131.8  41.8  220.4        16.8  12.7
# 5 2020-03-30   60.0    66.5     131.8  41.8  220.4        16.8  12.7
# 6 2020-03-31   63.6    66.7     141.3  42.9  234.8        17.8  13.0
#
#   J&K(UT) & Ladakh(UT) Chandigarh  ... Odisha West Bengal Sikkim  \
# 0                 47.7        2.8  ...   71.6       135.2    1.4
# 1                 45.6        2.4  ...   66.5       100.4    1.0
# 2                 44.7        2.4  ...   69.1       114.7    1.4
# 3                 42.9        2.4  ...   80.7       117.0    1.3
# 4                 45.3        2.2  ...   80.1       125.7    1.1
# 5                 45.3        2.2  ...   80.1       125.7    1.1
# 6                 40.2        2.3  ...   77.3       128.0    1.3
#
#   Arunachal Pradesh Assam Manipur Meghalaya Mizoram Nagaland Tripura
# 0               2.2  24.0     2.7       5.8     1.8      2.2     3.8
# 1               2.1  19.0     2.4       5.6     1.6      2.2     3.1
# 2               1.9  21.5     2.7       5.8     1.8      2.1     3.5
# 3               2.0  20.6     2.5       4.3     1.8      2.1     3.1
# 4               1.8  20.0     2.4       3.4     1.6      1.9     3.4
# 5               1.8  20.0     2.4       3.4     1.6      1.9     3.4
# 6               1.5  20.9     2.4       3.4     1.6      2.0     3.9
#
# [7 rows x 37 columns]
#
# Maximum Demand:
#          Date Punjab Haryana Rajasthan Delhi     UP Uttarakhand    HP  \
# 0 2020-03-22   5222    5698     10895  3215  15116        1712  1434
# 1 2020-03-23   3995    5064     10077  2282  13391        1131   954
# 2 2020-03-24   3965    4583      9610  2448  14232        1212  1305
# 3 2020-03-28   2973    3781      5599  2425  11359        1044   895
# 4 2020-03-29   3084    3668      7394  2241  13385        1004   825
# 5 2020-03-30   3084    3668      7394  2241  13385        1004   825
# 6 2020-03-31   3131    3793      8044  2302  13613        1041   827
#
#   J&K(UT) & Ladakh(UT) Chandigarh  ... Odisha West Bengal Sikkim  \
# 0                 2434        166  ...   3463        6734    102
# 1                 2067        143  ...   3408        5587     82
# 2                 2240        157  ...   4430        5798    113
# 3                 2161        149  ...   3929        6036     95
# 4                 2151        139  ...   3576        6209     86
# 5                 2151        139  ...   3576        6209     86
# 6                 1933        140  ...   3703        6545     97
#
#   Arunachal Pradesh Assam Manipur Meghalaya Mizoram Nagaland Tripura
# 0               121  1408     186       357     101      124     239
# 1               118  1160     190       320      99      124     216
# 2               121  1296     189       378     106      128     229
# 3               107  1337     176       277      94      113     249
# 4               114  1296     178       246      92      117     247
# 5               114  1296     178       246      92      117     247
# 6               110  1318     189       256      95      123     240
#
# [7 rows x 37 columns]

# %%
energy_met_df.to_csv('reports\\new_csv\\energy_2020.csv', index=False,mode='a')
maximum_demand_df.to_csv('reports\\new_csv\\max_2020.csv', index=False, mode='a')

# %% [markdown]
# Troubleshoot and understand the format of erroneous PDF files, and then appending to the required csv file

# %%
import pandas as pd
from tabula import read_pdf

# Specify the PDF file path
pdf_path = "reports\\2020\\21.03.20_NLDC_PSP.pdf"

# Extract tables from page 2 
tables = read_pdf(pdf_path, pages="2", multiple_tables=True)

# Check if any tables were found
if not tables:
    print("No tables found on page of the PDF.")
else:
    # Assuming there's only one table on page 2 (adjust if needed)
    #print(tables)
    df = tables[2]

df.head()
df.to_csv('test.csv', index=False)

# %%
import warnings
# Function to process a single PDF file
def process_pdf(pdf_path):
    try:
        # Suppress warnings from tabula
        warnings.filterwarnings("ignore", category=UserWarning, message=".*Fallback font.*")

        # Extract tables from page 2 
        tables = read_pdf(pdf_path, pages="2", multiple_tables=True)

        # Check if any tables were found
        if not tables:
            print(f"No tables found on page 2 of the PDF: {pdf_path}")
            return None, None

        df = pd.read_csv('test.csv')
        #df = tables[2]
        state_col = df.columns[1]
        max_demand_column = df.columns[3]
        energy_met_column = df.columns[5]
        df.rename(columns={state_col: 'State', max_demand_column: 'Max.Demand',energy_met_column: 'Energy Met'}, inplace=True)
        #df[['Max.Demand', 'Extra']] = df['Max.Demand'].str.split(' ', n=1, expand=True)
        #df[['Energy Met', 'Extra2']] = df['Energy Met'].str.split(' ', n=1, expand=True)
        df = df[['State', 'Max.Demand', 'Energy Met']]

        # Find the index to start from (Punjab)
        #df=df.drop(df.index[18]) drop a column of specified index
        index_to_keep_from = df[df['State'] == 'Punjab'].index[0]
        index_to_stop=df[df['State'] == 'Tripura'].index[0]
        df = df.loc[index_to_keep_from:index_to_stop]
        df.reset_index(drop=True, inplace=True)
        df.to_csv('test.csv', index=False)
        #df=df.drop(df.index[13])
        #df=df.drop(df.index[26])
        df.reset_index(drop=True, inplace=True)
        df.to_csv('test.csv', index=False,mode='a')

        # Extract date from the file path
        parts = pdf_path.split("\\")
        date_part = parts[-1].split("_")[0]
        day, month, year = map(int, date_part.split("."))
        date = pd.to_datetime(f'{int(year) + 2000}-{month}-{day}')

        return date, df

    except Exception as e:
        print(f"Error processing file {pdf_path}: {e}")
        return None, None
 
# Path to the single PDF file
pdf_path = "reports\\2020\\21.03.20_NLDC_PSP.pdf"

# Initialize lists to store data for energy_met and maximum_demand dataframes
energy_met_data = []
maximum_demand_data = []

# Process the single PDF file
date, df = process_pdf(pdf_path)
if date is not None and df is not None:
    try:
        states = df['State'].tolist()
        energy_met_data.append([date] + df['Energy Met'].tolist())
        maximum_demand_data.append([date] + df['Max.Demand'].tolist())
        print(f"Dataframe appended: {date}")
    except Exception as e:
        print(f"Error appending data for date {date}: {e}")


energy_met_df = pd.DataFrame(energy_met_data, columns=['Date'] + states)
maximum_demand_df = pd.DataFrame(maximum_demand_data, columns=['Date'] + states)


# Create energy_met and maximum_demand dataframes
if energy_met_data and maximum_demand_data:
    energy_met_df = pd.DataFrame(energy_met_data, columns=['Date'] + states)
    maximum_demand_df = pd.DataFrame(maximum_demand_data, columns=['Date'] + states)

    # Append dataframes to CSV file
    energy_met_csv_path = "reports\\new_csv\\energy_2020.csv"
    maximum_demand_csv_path = "reports\\new_csv\\max_2020.csv"
    energy_met_df.to_csv(energy_met_csv_path, index=False, header=False,mode='a')
    maximum_demand_df.to_csv(maximum_demand_csv_path, index=False,header=False,mode='a')
    print(f"Dataframes appended to CSV files: {energy_met_csv_path}, {maximum_demand_csv_path}")
else:
    print("No data was processed.")
# Out:
# Dataframe appended: 2020-03-21 00:00:00
# Dataframes appended to CSV files: reports\new_csv\energy_2020.csv, reports\new_csv\max_2020.csv

# %% [markdown]
# Consolidating individual csv files into 2 files
# - energy_states_consolidated
# - max_states_consolidated

# %%
import pandas as pd
import os

# Directory containing the CSV files
directory = 'reports\\new_csv'

# List all CSV files in the directory
energy_csv_files = [file for file in os.listdir(directory) if file.endswith('.csv') and file.startswith('energy')]
max_csv_files = [file for file in os.listdir(directory) if file.endswith('.csv') and file.startswith('max')]

# Read each CSV file and concatenate them into a single DataFrame
energy_dfs = []
for file in energy_csv_files:
    df = pd.read_csv(os.path.join(directory, file))
    energy_dfs.append(df)

max_dfs = []
for file in max_csv_files:
    df = pd.read_csv(os.path.join(directory, file))
    max_dfs.append(df)

# Concatenate all DataFrames into one
energy_result = pd.concat(energy_dfs, ignore_index=True)
energy_result.reset_index(drop=True, inplace=True)
max_result = pd.concat(max_dfs, ignore_index=True)
max_result.reset_index(drop=True, inplace=True)

# Write the consolidated DataFrame to a new CSV file
energy_result.to_csv('energy_states_consolidated.csv', index=False)
max_result.to_csv('max_states_consolidated.csv', index=False)

print("Consolidated CSV file saved successfully.")
# Out:
# Consolidated CSV file saved successfully.
